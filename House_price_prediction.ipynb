# %% [markdown]
# # Boston House Dataset- Linear Regression

# %% [markdown]
# Life cycle process of ML
#
# 1. Define Libraries.Define the metrics for which the model is getting optimised
#
# 2. Data cleansing and Wrangling
#
# 3. Feature Engineering
#
# 4. Data Pre-processing
#
# 5. Feature Selection
#
# 6. Split Train and Test dataset
#
# 7. Model selection
#
# 8. Model validation
#
# 9. Interprit the results

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import load_boston

# %%
boston= load_boston()

# %%
boston
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#         18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#         15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#         13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
# ...

# %%
boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
boston.data
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
boston.target
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
# ...

# %%
bos= pd.DataFrame(boston.data,columns=boston.feature_names)

# %%
bos
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
bos.shape
# Out:
# (506, 13)

# %%
bos['target']=boston.target

# %%
bos.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'target'],
#       dtype='object')

# %%
bos
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# ...

# %%
bos.shape
# Out:
# (506, 14)

# %%
bos.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
bos.skew()
# Out:
# CRIM       5.223149
# ZN         2.225666
# INDUS      0.295022
# CHAS       3.405904
# NOX        0.729308
# RM         0.403612
# AGE       -0.598963
# DIS        1.011781
# RAD        1.004815
# TAX        0.669956
# PTRATIO   -0.802325
# B         -2.890374
# LSTAT      0.906460
# target     1.108098
# dtype: float64

# %%
bos.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD        float64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# target     float64
# dtype: object

# %%
bos.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# target     0
# dtype: int64

# %%
sns.heatmap(bos.isnull())
# Out:
# <AxesSubplot:>

# %%
bos['CRIM'].plot.box()
# Out:
# <AxesSubplot:>

# %%
bos['ZN'].plot.box()
# Out:
# <AxesSubplot:>

# %%
bos['CHAS'].plot.box()
# Out:
# <AxesSubplot:>

# %%
bos['NOX'].plot.box()
# Out:
# <AxesSubplot:>

# %%
bos.plot(kind='box',subplots=True,layout=( 2,7))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-d2b782c227ed> in <module>
# ----> 1 bos.plot(kind='box',subplots=True,layout=( 2,7))
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     277         self._args_adjust()
# ...

# %%
#removing outliers
from scipy.stats import zscore
z=np.abs(zscore(bos))
z
# Out:
# array([[0.41978194, 0.28482986, 1.2879095 , ..., 1.0755623 , 0.15968566,
#         0.15968566],
#        [0.41733926, 0.48772236, 0.59338101, ..., 0.49243937, 0.10152429,
#         0.10152429],
#        [0.41734159, 0.48772236, 0.59338101, ..., 1.2087274 , 1.32424667,
#         1.32424667],
#        ...,
#        [0.41344658, 0.48772236, 0.11573841, ..., 0.98304761, 0.14880191,
#         0.14880191],
#        [0.40776407, 0.48772236, 0.11573841, ..., 0.86530163, 0.0579893 ,
#         0.0579893 ],
#        [0.41500016, 0.48772236, 0.11573841, ..., 0.66905833, 1.15724782,
#         1.15724782]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 55,  56,  57, 102, 141, 142, 152, 154, 155, 160, 162, 163, 199,
#        200, 201, 202, 203, 204, 208, 209, 210, 211, 212, 216, 218, 219,
#        220, 221, 222, 225, 234, 236, 256, 257, 262, 269, 273, 274, 276,
#        277, 282, 283, 283, 284, 347, 351, 352, 353, 353, 354, 355, 356,
#        357, 358, 363, 364, 364, 365, 367, 369, 370, 372, 373, 374, 374,
#        380, 398, 404, 405, 406, 410, 410, 411, 412, 412, 414, 414, 415,
#        416, 418, 418, 419, 423, 424, 425, 426, 427, 427, 429, 431, 436,
#        437, 438, 445, 450, 454, 455, 456, 457, 466], dtype=int64), array([ 1,  1,  1, 11, 12,  3,  3,  3,  3,  3,  3,  3,  1,  1,  1,  1,  1,
#         1,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  5,  3,  3,  1,  5,
#         5,  3,  3,  3,  3,  3,  3,  1,  3,  1,  1,  7,  7,  1,  7,  7,  7,
#         3,  3,  3,  3,  3,  5,  5,  5,  3,  3,  3, 12,  5, 12,  0,  0,  0,
#         0,  5,  0, 11, 11, 11, 12,  0, 12, 11, 11,  0, 11, 11, 11, 11, 11,
# ...

# %%
z[55][1]
# Out:
# 3.375038763517294

# %%
bos.skew()
# Out:
# CRIM       5.223149
# ZN         2.225666
# INDUS      0.295022
# CHAS       3.405904
# NOX        0.729308
# RM         0.403612
# AGE       -0.598963
# DIS        1.011781
# RAD        1.004815
# TAX        0.669956
# PTRATIO   -0.802325
# B         -2.890374
# LSTAT      0.906460
# target     1.108098
# Price      1.108098
# dtype: float64

# %%
bos['ZN'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
bos['RAD'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
bos['CRIM'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#bos['CRIM']=np.log(bos['CRIM'])
#bos['CRIM'].plot.hist()

# %%
from scipy.stats import boxcox
bos['CRIM']= boxcox(bos['CRIM'],0)

# %%
bos['CRIM'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
from scipy.stats import boxcox
bos['ZN']= boxcox(bos['ZN'],0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-7d58d2fd54ee> in <module>
#       1 from scipy.stats import boxcox
# ----> 2 bos['ZN']= boxcox(bos['ZN'],0)
#
# ~\anaconda3\lib\site-packages\scipy\stats\morestats.py in boxcox(x, lmbda, alpha)
#    1041
#    1042     if any(x <= 0):
# -> 1043         raise ValueError("Data must be positive.")
#    1044
#    1045     if lmbda is not None:  # single transformation
#
# ValueError: Data must be positive.

# %%
bos['Price']=bos.target

# %%
sns.scatterplot(bos['CRIM'],bos['Price'])
# Out:
# <AxesSubplot:xlabel='CRIM', ylabel='Price'>

# %%
sns.scatterplot(bos['B'],bos['Price'])
# Out:
# <AxesSubplot:xlabel='B', ylabel='Price'>

# %%
sns.scatterplot(bos['RM'],bos['Price'])
# Out:
# <AxesSubplot:xlabel='RM', ylabel='Price'>

# %%
sns.scatterplot(bos['AGE'],bos['Price'])
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='Price'>

# %%
sns.scatterplot(bos['LSTAT'],bos['Price'])
# Out:
# <AxesSubplot:xlabel='LSTAT', ylabel='Price'>

# %%
sns.pairplot(bos)

# %%
corr_hmap=bos.corr()
plt.figure(figsize=(7,7))
sns.heatmap(corr_hmap,annot=True)
plt.show()

# %%
bos.drop('LSTAT',axis=1,inplace=True)

# %%
bos.drop('target',axis=1,inplace=True)

# %%
bos_new=bos[(z<3).all(axis=1)]

# %%
bos.shape
# Out:
# (506, 13)

# %%
bos_new.shape
# Out:
# (415, 13)

# %%
bos=bos_new

# %%
bos
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0   -5.064036  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1   -3.600502   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2   -3.601235   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3   -3.430523   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4   -2.672924   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501 -2.770511   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502 -3.095111   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503 -2.800824   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504 -2.211009   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505 -3.048922   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  Price
# 0       15.3  396.90   24.0
# 1       17.8  396.90   21.6
# ...

# %%
x=bos.iloc[:,0:-1]

# %%
y=bos.iloc[:,-1]

# %%
x
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0   -5.064036  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1   -3.600502   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2   -3.601235   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3   -3.430523   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4   -2.672924   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501 -2.770511   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502 -3.095111   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503 -2.800824   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504 -2.211009   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505 -3.048922   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B
# 0       15.3  396.90
# 1       17.8  396.90
# 2       17.8  392.83
# ...

# %%
y.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: Price, dtype: float64

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train.shape
# Out:
# (290, 12)

# %%
y_train.shape
# Out:
# (290,)

# %%
lm= LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([ 2.72853485e-01, -1.58841918e-02, -2.38613377e-02,  4.39925874e-15,
#        -1.37042390e+01,  8.15121482e+00, -6.11417007e-02, -1.10046344e+00,
#         3.41054525e-02, -1.00280423e-02, -8.86054685e-01,  8.49254974e-03])

# %%
lm.intercept_
# Out:
# 4.482405989767702

# %%
bos.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'Price'],
#       dtype='object')

# %%
lm.score(x_train,y_train)
# Out:
# 0.7339768249352003

# %%
pred=lm.predict(x_test)
print("Predicted house prices",pred)
print("Actual-",y_test)
# Out:
# Predicted house prices [20.2366608  14.9219699  31.65902612 18.27365462 12.94169154 20.61951493
#  16.98677756 25.0631275  29.72839555 10.62872413 17.44068881 15.84158212
#   8.83909951 24.53827889 27.95654722 10.55817805 25.84613671 27.29224827
#  24.99188619 14.37754576 21.60705741 19.73300874 23.94254996 11.83033308
#  22.51398047 21.97849428 31.86522485 27.73607489 22.69227362 24.86428054
#  31.74655649 14.61445776 13.52774222 26.09464225 15.83536226 14.94531198
#  26.88761631 22.88641388 14.7845991  19.12394417 16.70480149 17.74771675
#  20.84435428 27.37351476 16.85342626 26.14160345 19.6508803  19.70133156
#  17.97842501 24.39602298 21.17245474 19.00570075 39.73964308 13.39205406
#  18.5994414  22.37860379 18.87245949 40.98017216 20.23925023 18.24564687
#  26.39133241 16.61428381 24.53985142 27.57707133 14.03996216  5.13205668
#  33.74281819 19.37727159 18.87531793 22.51272667 35.35192091 20.34311398
#  24.38815    24.83152411 15.35834558 22.96384929 16.32918888 17.72896049
# ...

# %%
print("Error")
print("Mean Absolute error",mean_absolute_error(pred,y_test))
print("Mean predicted error",mean_squared_error(pred,y_test))
print("Root mean squared error",np.sqrt(mean_squared_error(pred,y_test)))
# Out:
# Error
# Mean Absolute error 2.680434257879442
# Mean predicted error 24.517119867910523
# Root mean squared error 4.951476534116922

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# 0.5704734202608119

# %%
#predict the house price by giving the value
t=np.array([0.00721,18.7,3.5,0.0,0,643,72.54,2.55,2.00,244.66,12.9,23.66])

# %%
t.shape
# Out:
# (12,)

# %%
t=t.reshape(1,-1)

# %%
t
# Out:
# array([[7.2100e-03, 1.8700e+01, 3.5000e+00, 0.0000e+00, 0.0000e+00,
#         6.4300e+02, 7.2540e+01, 2.5500e+00, 2.0000e+00, 2.4466e+02,
#         1.2900e+01, 2.3660e+01]])

# %%
t.shape
# Out:
# (1, 12)

# %%
lm.predict(t)
# Out:
# array([5224.47913384])
